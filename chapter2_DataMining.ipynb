# %% [markdown]
# <a href="https://colab.research.google.com/github/sararanjbarz/EDA-of-diabetes-datasets/blob/main/chapter2_DataMining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **EDA of diabetes datasets**

# %%
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt

data = datasets.load_diabetes()

df = pd.DataFrame(data.data,columns=data.feature_names)
df['target'] = pd.Series(data.target)

df.head()
# Out:
#         age       sex       bmi        bp  ...        s4        s5        s6  target
# 0  0.038076  0.050680  0.061696  0.021872  ... -0.002592  0.019908 -0.017646   151.0
# 1 -0.001882 -0.044642 -0.051474 -0.026328  ... -0.039493 -0.068330 -0.092204    75.0
# 2  0.085299  0.050680  0.044451 -0.005671  ... -0.002592  0.002864 -0.025930   141.0
# 3 -0.089063 -0.044642 -0.011595 -0.036656  ...  0.034309  0.022692 -0.009362   206.0
# 4  0.005383 -0.044642 -0.036385  0.021872  ... -0.002592 -0.031991 -0.046641   135.0
#
# [5 rows x 11 columns]

# %%
df2=df.drop('target', axis=1)
df2
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 0    0.038076  0.050680  0.061696  ... -0.002592  0.019908 -0.017646
# 1   -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068330 -0.092204
# 2    0.085299  0.050680  0.044451  ... -0.002592  0.002864 -0.025930
# 3   -0.089063 -0.044642 -0.011595  ...  0.034309  0.022692 -0.009362
# 4    0.005383 -0.044642 -0.036385  ... -0.002592 -0.031991 -0.046641
# ..        ...       ...       ...  ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  ... -0.002592  0.031193  0.007207
# 438 -0.005515  0.050680 -0.015906  ...  0.034309 -0.018118  0.044485
# 439  0.041708  0.050680 -0.015906  ... -0.011080 -0.046879  0.015491
# 440 -0.045472 -0.044642  0.039062  ...  0.026560  0.044528 -0.025930
# 441 -0.045472 -0.044642 -0.073030  ... -0.039493 -0.004220  0.003064
#
# [442 rows x 10 columns]

# %%
fig = plt.figure(figsize=(10,7))
df2.boxplot()
plt.show()

# %%
import seaborn as sns
sns.pairplot(df,hue='target')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
sns.heatmap(df.corr(method="pearson"), cmap="YlGnBu", linecolor="white",linewidths=1,cbar=1, annot= True)
plt.show()
